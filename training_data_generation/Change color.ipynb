# %%
import cv2
import numpy
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
bishop_img = cv2.imread("H:\\AR-ExtendingOnlineGames\\3d_pieces\\images\\Bishop\\e10_a0.0.jpg")
plt.imshow(bishop_img)
