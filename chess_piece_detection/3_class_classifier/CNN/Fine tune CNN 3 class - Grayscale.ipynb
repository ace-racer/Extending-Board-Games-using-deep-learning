# %%
import cv2
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import numpy as np
import os
import random
from collections import Counter, defaultdict
from itertools import product, combinations
import math
import cv2
from sklearn.model_selection import train_test_split

random.seed(42)

# %matplotlib inline

# %%
import keras
from keras.layers import Input, Conv2D, Lambda, average, Dense, Flatten,MaxPooling2D, BatchNormalization, Dropout, Activation, Subtract, subtract
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
import numpy.random as rng
# Out:
# Using TensorFlow backend.

# %%
IMAGE_SIZE = (70, 70)

def auto_canny(image, sigma=0.33):
	# compute the median of the single channel pixel intensities
	v = np.median(image)
 
	# apply automatic Canny edge detection using the computed median
	lower = int(max(0, (1.0 - sigma) * v))
	upper = int(min(255, (1.0 + sigma) * v))
	edged = cv2.Canny(image, lower, upper)
 
	# return the edged image
	return edged

def process_image(image_location):
    """
        Given the image location, process the image
    """
    # print(image_location)
    
    image = cv2.imread(image_location)
    
    if image.shape[0] != IMAGE_SIZE[0] or image.shape[1] != IMAGE_SIZE[1]:
        # print("Resizing the image: {0}".format(image_location))
        resized_image = cv2.resize(image, IMAGE_SIZE, interpolation = cv2.INTER_AREA)
    else:
        resized_image = image
    
    gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
    
    # get the edges from the image
    edges = auto_canny(gray)
    #print(edges.shape)
    
    
    # assert(denoised != edges)
    # add the two images in a weighted manner
    weighted_sum = cv2.addWeighted(gray, 0.8, edges, 0.2, 0)
       
    return weighted_sum

# %%
type_locations = {"b": ["bb", "wb"], "n": ["bn", "wn"], "k": ["bk", "wk"], "p": ["bp", "wp"], "q": ["bq", "wq"], "r": ["br", "wr"]}
type_name_to_label = { "p":0, "b":1, "n":2, "r":3, "q": 4, "k":5 }

# %% [markdown]
# ## The below cell need to be replaced with the location of the new data

# %%
def get_features_labels(data_path):
    X, y = [], []
    features_with_labels = []
    
    for type_name in type_locations:
        for folder_name in type_locations[type_name]:
            piece_type_folder = os.path.join(data_path, folder_name)
            for f in (os.listdir(piece_type_folder)):
                if f.endswith(".jpg"):  

                    img_file_loc = os.path.join(piece_type_folder, f)
                    grayscale_image = process_image(img_file_loc)
                    grayscale_image = grayscale_image[..., np.newaxis]
                    label = type_name_to_label[type_name]
                    features_with_labels.append({"feature": grayscale_image, "label": label})   
                    
    random.shuffle(features_with_labels)
    #print(X[0][0])
    #print(X[0][1])
    X = [x["feature"] for x in features_with_labels]
    y = [x["label"] for x in features_with_labels]
    
    X = np.array(X)
    X = X.astype('float32')
    X /= 255

    return X, np.array(y)

# %%
X_train, y_train = get_features_labels("C:\\Users\\issuser\\Desktop\\ExtendingBoardGamesOnline\\data\\sriraj_v1\\train")
X_test, y_test = get_features_labels("C:\\Users\\issuser\\Desktop\\ExtendingBoardGamesOnline\\data\\sriraj_v1\\test")
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1581, 70, 70, 1)
# (1581,)
# (60, 70, 70, 1)
# (60,)

# %%
# batch size
batch_size = 64


# number of training epochs
epochs = 150

required_input_shape = (*IMAGE_SIZE, 1)

# %%
model_folder_name = "fine_tune/models"
tensorboard_logs_folder_location = "fine_tune/logs"

# %%
def load_3_class_cnn_model(trained_3_class_classifier_location):
    """
        Load the 3 class CNN model
    """
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='valid', input_shape=required_input_shape))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(64, (3, 3)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
	
    model.add(Conv2D(128, (3, 3)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Dropout(0.5))

    model.add(Flatten())
    model.add(Dense(256))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.6))
    
    model.add(Dense(3))
    model.add(Activation('softmax'))
    model.summary()

    
    # load the model weights
    model.load_weights(trained_3_class_classifier_location)
                           
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    
    return model

# %%
trained_model = load_3_class_cnn_model("best_model/custom_cnn_95.hdf5")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 68, 68, 32)        320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 68, 68, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 68, 68, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 34, 34, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              12847104
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation_4 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 1542
# _________________________________________________________________
# activation_6 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 13,475,974
# Trainable params: 13,470,918
# Non-trainable params: 5,056
# _________________________________________________________________

# %%
# checkpoint
if not os.path.exists(model_folder_name):
    os.makedirs(model_folder_name)

# tensorboard logs
if not os.path.exists(tensorboard_logs_folder_location):
    os.makedirs(tensorboard_logs_folder_location)

filepath = os.path.join(model_folder_name, "3_class_cnn_fine_tuned.hdf5")
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

earlystop = EarlyStopping(monitor='val_acc', min_delta=0.0001, patience=20, verbose=1, mode='max')

tensorboard = TensorBoard(log_dir=tensorboard_logs_folder_location, histogram_freq=0, write_graph=True, write_images=True)

callbacks_list = [checkpoint, earlystop, tensorboard]

adam = Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
trained_model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

hist = trained_model.fit(X_train, y_train, shuffle=True, batch_size=batch_size,
                 epochs=epochs, verbose=1,
                 validation_data=(X_test, y_test), callbacks=callbacks_list)

# Evaluating the model on the test data
score, accuracy = trained_model.evaluate(X_test, y_test, verbose=0)
print('Test score:', score)
print('Test accuracy:', accuracy)
# Out:
# Train on 1581 samples, validate on 60 samples
# Epoch 1/150
# 1581/1581 [==============================] - 3s 2ms/step - loss: 2.9028 - acc: 0.2739 - val_loss: 2.3890 - val_acc: 0.3333
#
# Epoch 00001: val_acc improved from -inf to 0.33333, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 2/150
# 1581/1581 [==============================] - 1s 362us/step - loss: 2.6580 - acc: 0.2872 - val_loss: 2.2404 - val_acc: 0.3167
#
# Epoch 00002: val_acc did not improve from 0.33333
# Epoch 3/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 2.4462 - acc: 0.2985 - val_loss: 2.1380 - val_acc: 0.3833
#
# Epoch 00003: val_acc improved from 0.33333 to 0.38333, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 4/150
# 1581/1581 [==============================] - 1s 363us/step - loss: 2.2563 - acc: 0.3163 - val_loss: 2.0205 - val_acc: 0.3833
#
# Epoch 00004: val_acc did not improve from 0.38333
# Epoch 5/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 2.2292 - acc: 0.3055 - val_loss: 1.9178 - val_acc: 0.3500
#
# Epoch 00005: val_acc did not improve from 0.38333
# Epoch 6/150
# 1581/1581 [==============================] - 1s 364us/step - loss: 2.0832 - acc: 0.3460 - val_loss: 1.8121 - val_acc: 0.3667
#
# Epoch 00006: val_acc did not improve from 0.38333
# Epoch 7/150
# 1581/1581 [==============================] - 1s 366us/step - loss: 2.0785 - acc: 0.3397 - val_loss: 1.7323 - val_acc: 0.3833
#
# Epoch 00007: val_acc did not improve from 0.38333
# Epoch 8/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 1.9460 - acc: 0.3567 - val_loss: 1.6580 - val_acc: 0.4333
#
# Epoch 00008: val_acc improved from 0.38333 to 0.43333, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 9/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 1.8602 - acc: 0.3846 - val_loss: 1.5931 - val_acc: 0.4667
#
# Epoch 00009: val_acc improved from 0.43333 to 0.46667, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 10/150
# 1581/1581 [==============================] - 1s 364us/step - loss: 1.8614 - acc: 0.3669 - val_loss: 1.5309 - val_acc: 0.4833
#
# Epoch 00010: val_acc improved from 0.46667 to 0.48333, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 11/150
# 1581/1581 [==============================] - 1s 367us/step - loss: 1.7835 - acc: 0.4029 - val_loss: 1.4853 - val_acc: 0.4833
#
# Epoch 00011: val_acc did not improve from 0.48333
# Epoch 12/150
# 1581/1581 [==============================] - 1s 370us/step - loss: 1.7199 - acc: 0.4175 - val_loss: 1.4423 - val_acc: 0.5833
#
# Epoch 00012: val_acc improved from 0.48333 to 0.58333, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 13/150
# 1581/1581 [==============================] - 1s 367us/step - loss: 1.7279 - acc: 0.4086 - val_loss: 1.4075 - val_acc: 0.5833
#
# Epoch 00013: val_acc did not improve from 0.58333
# Epoch 14/150
# 1581/1581 [==============================] - 1s 367us/step - loss: 1.6525 - acc: 0.4326 - val_loss: 1.3727 - val_acc: 0.6000
#
# Epoch 00014: val_acc improved from 0.58333 to 0.60000, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 15/150
# 1581/1581 [==============================] - 1s 369us/step - loss: 1.5884 - acc: 0.4459 - val_loss: 1.3388 - val_acc: 0.6000
#
# Epoch 00015: val_acc did not improve from 0.60000
# Epoch 16/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 1.5933 - acc: 0.4497 - val_loss: 1.3152 - val_acc: 0.5833
#
# Epoch 00016: val_acc did not improve from 0.60000
# Epoch 17/150
# 1581/1581 [==============================] - 1s 366us/step - loss: 1.5078 - acc: 0.4700 - val_loss: 1.2870 - val_acc: 0.6167
#
# Epoch 00017: val_acc improved from 0.60000 to 0.61667, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 18/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 1.4766 - acc: 0.4744 - val_loss: 1.2610 - val_acc: 0.6333
#
# Epoch 00018: val_acc improved from 0.61667 to 0.63333, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 19/150
# 1581/1581 [==============================] - 1s 367us/step - loss: 1.4439 - acc: 0.4908 - val_loss: 1.2331 - val_acc: 0.6333
#
# Epoch 00019: val_acc did not improve from 0.63333
# Epoch 20/150
# 1581/1581 [==============================] - 1s 367us/step - loss: 1.3637 - acc: 0.5085 - val_loss: 1.2153 - val_acc: 0.6500
#
# Epoch 00020: val_acc improved from 0.63333 to 0.65000, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 21/150
# 1581/1581 [==============================] - 1s 369us/step - loss: 1.3869 - acc: 0.5066 - val_loss: 1.1958 - val_acc: 0.6500
#
# Epoch 00021: val_acc did not improve from 0.65000
# Epoch 22/150
# 1581/1581 [==============================] - 1s 368us/step - loss: 1.3696 - acc: 0.5136 - val_loss: 1.1776 - val_acc: 0.6667
#
# Epoch 00022: val_acc improved from 0.65000 to 0.66667, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 23/150
# 1581/1581 [==============================] - 1s 370us/step - loss: 1.3869 - acc: 0.5035 - val_loss: 1.1634 - val_acc: 0.6833
#
# Epoch 00023: val_acc improved from 0.66667 to 0.68333, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 24/150
# 1581/1581 [==============================] - 1s 370us/step - loss: 1.2723 - acc: 0.5370 - val_loss: 1.1466 - val_acc: 0.6833
#
# Epoch 00024: val_acc did not improve from 0.68333
# Epoch 25/150
# 1581/1581 [==============================] - 1s 371us/step - loss: 1.2744 - acc: 0.5326 - val_loss: 1.1308 - val_acc: 0.6833
#
# Epoch 00025: val_acc did not improve from 0.68333
# Epoch 26/150
# 1581/1581 [==============================] - 1s 369us/step - loss: 1.2395 - acc: 0.5515 - val_loss: 1.1134 - val_acc: 0.6833
#
# Epoch 00026: val_acc did not improve from 0.68333
# Epoch 27/150
# 1581/1581 [==============================] - 1s 372us/step - loss: 1.2317 - acc: 0.5579 - val_loss: 1.1016 - val_acc: 0.6833
#
# Epoch 00027: val_acc did not improve from 0.68333
# Epoch 28/150
# 1581/1581 [==============================] - 1s 368us/step - loss: 1.2067 - acc: 0.5661 - val_loss: 1.0891 - val_acc: 0.6833
#
# Epoch 00028: val_acc did not improve from 0.68333
# Epoch 29/150
# 1581/1581 [==============================] - 1s 371us/step - loss: 1.2083 - acc: 0.5497 - val_loss: 1.0789 - val_acc: 0.6833
#
# Epoch 00029: val_acc did not improve from 0.68333
# Epoch 30/150
# 1581/1581 [==============================] - 1s 372us/step - loss: 1.1881 - acc: 0.5636 - val_loss: 1.0682 - val_acc: 0.6833
#
# Epoch 00030: val_acc did not improve from 0.68333
# Epoch 31/150
# 1581/1581 [==============================] - 1s 370us/step - loss: 1.0997 - acc: 0.6066 - val_loss: 1.0557 - val_acc: 0.6833
#
# Epoch 00031: val_acc did not improve from 0.68333
# Epoch 32/150
# 1581/1581 [==============================] - 1s 370us/step - loss: 1.1261 - acc: 0.5927 - val_loss: 1.0494 - val_acc: 0.7000
#
# Epoch 00032: val_acc improved from 0.68333 to 0.70000, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 33/150
# 1581/1581 [==============================] - 1s 369us/step - loss: 1.0961 - acc: 0.6040 - val_loss: 1.0448 - val_acc: 0.7167
#
# Epoch 00033: val_acc improved from 0.70000 to 0.71667, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 34/150
# 1581/1581 [==============================] - 1s 368us/step - loss: 1.1194 - acc: 0.5946 - val_loss: 1.0351 - val_acc: 0.7000
#
# Epoch 00034: val_acc did not improve from 0.71667
# Epoch 35/150
# 1581/1581 [==============================] - 1s 380us/step - loss: 1.0792 - acc: 0.6186 - val_loss: 1.0230 - val_acc: 0.7000
#
# Epoch 00035: val_acc did not improve from 0.71667
# Epoch 36/150
# 1581/1581 [==============================] - 1s 372us/step - loss: 1.0557 - acc: 0.6218 - val_loss: 1.0133 - val_acc: 0.7000
#
# Epoch 00036: val_acc did not improve from 0.71667
# Epoch 37/150
# 1581/1581 [==============================] - 1s 369us/step - loss: 1.0590 - acc: 0.6091 - val_loss: 1.0017 - val_acc: 0.7000
#
# Epoch 00037: val_acc did not improve from 0.71667
# Epoch 38/150
# 1581/1581 [==============================] - 1s 372us/step - loss: 1.0302 - acc: 0.6357 - val_loss: 0.9889 - val_acc: 0.7000
#
# Epoch 00038: val_acc did not improve from 0.71667
# Epoch 39/150
# 1581/1581 [==============================] - 1s 363us/step - loss: 1.0021 - acc: 0.6515 - val_loss: 0.9817 - val_acc: 0.7000
#
# Epoch 00039: val_acc did not improve from 0.71667
# Epoch 40/150
# 1581/1581 [==============================] - 1s 366us/step - loss: 0.9957 - acc: 0.6553 - val_loss: 0.9751 - val_acc: 0.7000
#
# Epoch 00040: val_acc did not improve from 0.71667
# Epoch 41/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 1.0072 - acc: 0.6464 - val_loss: 0.9677 - val_acc: 0.7000
#
# Epoch 00041: val_acc did not improve from 0.71667
# Epoch 42/150
# 1581/1581 [==============================] - 1s 364us/step - loss: 0.9528 - acc: 0.6584 - val_loss: 0.9625 - val_acc: 0.7000
#
# Epoch 00042: val_acc did not improve from 0.71667
# Epoch 43/150
# 1581/1581 [==============================] - 1s 373us/step - loss: 0.9429 - acc: 0.6616 - val_loss: 0.9537 - val_acc: 0.7000
#
# Epoch 00043: val_acc did not improve from 0.71667
# Epoch 44/150
# 1581/1581 [==============================] - 1s 368us/step - loss: 0.9397 - acc: 0.6679 - val_loss: 0.9484 - val_acc: 0.7000
#
# Epoch 00044: val_acc did not improve from 0.71667
# Epoch 45/150
# 1581/1581 [==============================] - 1s 367us/step - loss: 0.9211 - acc: 0.6793 - val_loss: 0.9438 - val_acc: 0.7000
#
# Epoch 00045: val_acc did not improve from 0.71667
# Epoch 46/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 0.8662 - acc: 0.6894 - val_loss: 0.9373 - val_acc: 0.7167
#
# Epoch 00046: val_acc did not improve from 0.71667
# Epoch 47/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 0.8954 - acc: 0.6774 - val_loss: 0.9336 - val_acc: 0.7000
#
# Epoch 00047: val_acc did not improve from 0.71667
# Epoch 48/150
# 1581/1581 [==============================] - 1s 364us/step - loss: 0.8755 - acc: 0.6958 - val_loss: 0.9285 - val_acc: 0.7000
#
# Epoch 00048: val_acc did not improve from 0.71667
# Epoch 49/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 0.8766 - acc: 0.6964 - val_loss: 0.9260 - val_acc: 0.7000
#
# Epoch 00049: val_acc did not improve from 0.71667
# Epoch 50/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 0.8377 - acc: 0.7008 - val_loss: 0.9226 - val_acc: 0.7000
#
# Epoch 00050: val_acc did not improve from 0.71667
# Epoch 51/150
# 1581/1581 [==============================] - 1s 366us/step - loss: 0.8124 - acc: 0.7116 - val_loss: 0.9146 - val_acc: 0.7000
#
# Epoch 00051: val_acc did not improve from 0.71667
# Epoch 52/150
# 1581/1581 [==============================] - 1s 365us/step - loss: 0.8346 - acc: 0.7059 - val_loss: 0.9104 - val_acc: 0.7000
#
# Epoch 00052: val_acc did not improve from 0.71667
# Epoch 53/150
# 1581/1581 [==============================] - 1s 366us/step - loss: 0.7887 - acc: 0.7299 - val_loss: 0.9121 - val_acc: 0.7000
#
# Epoch 00053: val_acc did not improve from 0.71667
# Epoch 00053: early stopping
# Test score: 0.9121223648389181
# Test accuracy: 0.699999988079071

# %% [markdown]
# # Load the fine-tuned model and perform predictions on the test set and visualize the mispredicted images
