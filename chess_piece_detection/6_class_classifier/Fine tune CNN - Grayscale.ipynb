# %%
import cv2
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import numpy as np
import os
import random
from collections import Counter, defaultdict
from itertools import product, combinations
import math
import cv2
from sklearn.model_selection import train_test_split

random.seed(42)

# %matplotlib inline

# %%
import keras
from keras.layers import Input, Conv2D, Lambda, average, Dense, Flatten,MaxPooling2D, BatchNormalization, Dropout, Activation, Subtract, subtract
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
import numpy.random as rng
# Out:
# /home/anurag/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
IMAGE_SIZE = (70, 70)

def auto_canny(image, sigma=0.33):
	# compute the median of the single channel pixel intensities
	v = np.median(image)
 
	# apply automatic Canny edge detection using the computed median
	lower = int(max(0, (1.0 - sigma) * v))
	upper = int(min(255, (1.0 + sigma) * v))
	edged = cv2.Canny(image, lower, upper)
 
	# return the edged image
	return edged

def process_image(image_location):
    """
        Given the image location, process the image
    """
    # print(image_location)
    
    image = cv2.imread(image_location)
    
    if image.shape[0] != IMAGE_SIZE[0] or image.shape[1] != IMAGE_SIZE[1]:
        # print("Resizing the image: {0}".format(image_location))
        resized_image = cv2.resize(image, IMAGE_SIZE, interpolation = cv2.INTER_AREA)
    else:
        resized_image = image
    
    gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
    
    # get the edges from the image
    edges = auto_canny(gray)
    #print(edges.shape)
    
    
    # assert(denoised != edges)
    # add the two images in a weighted manner
    weighted_sum = cv2.addWeighted(gray, 0.8, edges, 0.2, 0)
       
    return weighted_sum

# %%
type_locations = {"b": ["bb", "wb"], "n": ["bn", "wn"], "k": ["bk", "wk"], "p": ["bp", "wp"], "q": ["bq", "wq"], "r": ["br", "wr"]}
type_name_to_label = { "p":0, "b":1, "n":2, "r":3, "q": 4, "k":5 }

# %% [markdown]
# ## The below cell need to be replaced with the location of the new data

# %%
def get_features_labels(data_path):
    X, y = [], []
    features_with_labels = []
    
    for type_name in type_locations:
        for folder_name in type_locations[type_name]:
            piece_type_folder = os.path.join(data_path, folder_name)
            for f in (os.listdir(piece_type_folder)):
                if f.endswith(".jpg"):  

                    img_file_loc = os.path.join(piece_type_folder, f)
                    grayscale_image = process_image(img_file_loc)
                    grayscale_image = grayscale_image[..., np.newaxis]
                    label = type_name_to_label[type_name]
                    features_with_labels.append({"feature": grayscale_image, "label": label})   
                    
    random.shuffle(features_with_labels)
    #print(X[0][0])
    #print(X[0][1])
    X = [x["feature"] for x in features_with_labels]
    y = [x["label"] for x in features_with_labels]
    
    X = np.array(X)
    X = X.astype('float32')
    X /= 255

    return X, np.array(y)

# %%
X_train, y_train = get_features_labels("C:\\Users\\issuser\\Desktop\\ExtendingBoardGamesOnline\\data\\Chess ID Public Data\\train")
X_test, y_test = get_features_labels("C:\\Users\\issuser\\Desktop\\ExtendingBoardGamesOnline\\data\\Chess ID Public Data\\test")
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (6899, 70, 70, 1)
# (6899,)
# (185, 70, 70, 1)
# (185,)

# %%
# batch size
batch_size = 64


# number of training epochs
epochs = 150

required_input_shape = (*IMAGE_SIZE, 1)

# %%
model_folder_name = "fine_tune/models"
tensorboard_logs_folder_location = "fine_tune/logs"

# %%
def load_6_class_cnn_model(model_weights_location):
    """"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='valid', input_shape=required_input_shape))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(64, (3, 3)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(128, (3, 3)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Dropout(0.5))

    model.add(Flatten())
    
    model.add(Dense(2048))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    
    model.add(Dense(256))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.6))
    
    model.add(Dense(6))
    model.add(Activation('softmax'))
    model.summary()

    # load the model weights
    model.load_weights(model_weights_location)
                           
    adam = Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    
    return model

# %%
trained_model = load_6_class_cnn_model("models/6_class_cnn.hdf5")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 68, 68, 32)        320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 68, 68, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 68, 68, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 34, 34, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              12847104
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation_4 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 1542
# _________________________________________________________________
# activation_6 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 13,475,974
# Trainable params: 13,470,918
# Non-trainable params: 5,056
# _________________________________________________________________

# %%
# checkpoint
if not os.path.exists(model_folder_name):
    os.makedirs(model_folder_name)

# tensorboard logs
if not os.path.exists(tensorboard_logs_folder_location):
    os.makedirs(tensorboard_logs_folder_location)

filepath = os.path.join(model_folder_name, "6_class_cnn_fine_tuned.hdf5")
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

earlystop = EarlyStopping(monitor='val_acc', min_delta=0.0001, patience=20, verbose=1, mode='max')

tensorboard = TensorBoard(log_dir=tensorboard_logs_folder_location, histogram_freq=0, write_graph=True, write_images=True)

callbacks_list = [checkpoint, earlystop, tensorboard]

adam = Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
trained_model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

hist = trained_model.fit(X_train, y_train, shuffle=True, batch_size=batch_size,
                 epochs=epochs, verbose=1,
                 validation_data=(X_test, y_test), callbacks=callbacks_list)

# Evaluating the model on the test data
score, accuracy = trained_model.evaluate(X_test, y_test, verbose=0)
print('Test score:', score)
print('Test accuracy:', accuracy)
# Out:
# Train on 6899 samples, validate on 185 samples
# Epoch 1/150
# 6899/6899 [==============================] - 3s 436us/step - loss: 0.7957 - acc: 0.6988 - val_loss: 1.0668 - val_acc: 0.6216
#
# Epoch 00001: val_acc improved from -inf to 0.62162, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 2/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.8003 - acc: 0.6955 - val_loss: 1.0540 - val_acc: 0.6270
#
# Epoch 00002: val_acc improved from 0.62162 to 0.62703, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 3/150
# 6899/6899 [==============================] - 2s 347us/step - loss: 0.8063 - acc: 0.6918 - val_loss: 1.0535 - val_acc: 0.6216
#
# Epoch 00003: val_acc did not improve from 0.62703
# Epoch 4/150
# 6899/6899 [==============================] - 2s 346us/step - loss: 0.7941 - acc: 0.6933 - val_loss: 1.0570 - val_acc: 0.6324 0.7916
#
# Epoch 00004: val_acc improved from 0.62703 to 0.63243, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 5/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7719 - acc: 0.7079 - val_loss: 1.0695 - val_acc: 0.6270
#
# Epoch 00005: val_acc did not improve from 0.63243
# Epoch 6/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7759 - acc: 0.7066 - val_loss: 1.0571 - val_acc: 0.6270
#
# Epoch 00006: val_acc did not improve from 0.63243
# Epoch 7/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7824 - acc: 0.7034 - val_loss: 1.0678 - val_acc: 0.6270
#
# Epoch 00007: val_acc did not improve from 0.63243
# Epoch 8/150
# 6899/6899 [==============================] - 2s 351us/step - loss: 0.7720 - acc: 0.7082 - val_loss: 1.0663 - val_acc: 0.6216
#
# Epoch 00008: val_acc did not improve from 0.63243
# Epoch 9/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7431 - acc: 0.7174 - val_loss: 1.0542 - val_acc: 0.6270
#
# Epoch 00009: val_acc did not improve from 0.63243
# Epoch 10/150
# 6899/6899 [==============================] - 2s 349us/step - loss: 0.7571 - acc: 0.7116 - val_loss: 1.0600 - val_acc: 0.6216
#
# Epoch 00010: val_acc did not improve from 0.63243
# Epoch 11/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7850 - acc: 0.7040 - val_loss: 1.0508 - val_acc: 0.6216
#
# Epoch 00011: val_acc did not improve from 0.63243
# Epoch 12/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7552 - acc: 0.7104 - val_loss: 1.0663 - val_acc: 0.6216
#
# Epoch 00012: val_acc did not improve from 0.63243
# Epoch 13/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7274 - acc: 0.7214 - val_loss: 1.0682 - val_acc: 0.6270
#
# Epoch 00013: val_acc did not improve from 0.63243
# Epoch 14/150
# 6899/6899 [==============================] - 2s 349us/step - loss: 0.7259 - acc: 0.7262 - val_loss: 1.0690 - val_acc: 0.6108
#
# Epoch 00014: val_acc did not improve from 0.63243
# Epoch 15/150
# 6899/6899 [==============================] - 2s 349us/step - loss: 0.7273 - acc: 0.7204 - val_loss: 1.0541 - val_acc: 0.6162
#
# Epoch 00015: val_acc did not improve from 0.63243
# Epoch 16/150
# 6899/6899 [==============================] - ETA: 0s - loss: 0.7226 - acc: 0.726 - 2s 350us/step - loss: 0.7276 - acc: 0.7247 - val_loss: 1.0644 - val_acc: 0.6270
#
# Epoch 00016: val_acc did not improve from 0.63243
# Epoch 17/150
# 6899/6899 [==============================] - 2s 349us/step - loss: 0.7302 - acc: 0.7268 - val_loss: 1.0643 - val_acc: 0.6324
#
# Epoch 00017: val_acc did not improve from 0.63243
# Epoch 18/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7283 - acc: 0.7226 - val_loss: 1.0675 - val_acc: 0.6270
#
# Epoch 00018: val_acc did not improve from 0.63243
# Epoch 19/150
# 6899/6899 [==============================] - 2s 349us/step - loss: 0.6951 - acc: 0.7374 - val_loss: 1.0725 - val_acc: 0.6216
#
# Epoch 00019: val_acc did not improve from 0.63243
# Epoch 20/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7125 - acc: 0.7316 - val_loss: 1.0712 - val_acc: 0.6378
#
# Epoch 00020: val_acc improved from 0.63243 to 0.63784, saving model to fine_tune/models\6_class_cnn_fine_tuned.hdf5
# Epoch 21/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7014 - acc: 0.7297 - val_loss: 1.0323 - val_acc: 0.6162
#
# Epoch 00021: val_acc did not improve from 0.63784
# Epoch 22/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.7006 - acc: 0.7342 - val_loss: 1.0510 - val_acc: 0.6216
#
# Epoch 00022: val_acc did not improve from 0.63784
# Epoch 23/150
# 6899/6899 [==============================] - 2s 349us/step - loss: 0.7032 - acc: 0.7274 - val_loss: 1.0569 - val_acc: 0.6270
#
# Epoch 00023: val_acc did not improve from 0.63784
# Epoch 24/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6904 - acc: 0.7391 - val_loss: 1.0705 - val_acc: 0.6162
#
# Epoch 00024: val_acc did not improve from 0.63784
# Epoch 25/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6892 - acc: 0.7326 - val_loss: 1.0475 - val_acc: 0.6270
#
# Epoch 00025: val_acc did not improve from 0.63784
# Epoch 26/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6933 - acc: 0.7381 - val_loss: 1.0334 - val_acc: 0.6216
#
# Epoch 00026: val_acc did not improve from 0.63784
# Epoch 27/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6679 - acc: 0.7463 - val_loss: 1.0588 - val_acc: 0.6216
#
# Epoch 00027: val_acc did not improve from 0.63784
# Epoch 28/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6807 - acc: 0.7400 - val_loss: 1.0518 - val_acc: 0.6270
#
# Epoch 00028: val_acc did not improve from 0.63784
# Epoch 29/150
# 6899/6899 [==============================] - 2s 351us/step - loss: 0.6548 - acc: 0.7532 - val_loss: 1.0658 - val_acc: 0.6270
#
# Epoch 00029: val_acc did not improve from 0.63784
# Epoch 30/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6789 - acc: 0.7394 - val_loss: 1.0798 - val_acc: 0.6216
#
# Epoch 00030: val_acc did not improve from 0.63784
# Epoch 31/150
# 6899/6899 [==============================] - 2s 353us/step - loss: 0.6665 - acc: 0.7479 - val_loss: 1.0709 - val_acc: 0.6216
#
# Epoch 00031: val_acc did not improve from 0.63784
# Epoch 32/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6558 - acc: 0.7443 - val_loss: 1.0631 - val_acc: 0.6216
#
# Epoch 00032: val_acc did not improve from 0.63784
# Epoch 33/150
# 6899/6899 [==============================] - 2s 352us/step - loss: 0.6389 - acc: 0.7566 - val_loss: 1.0675 - val_acc: 0.6270
#
# Epoch 00033: val_acc did not improve from 0.63784
# Epoch 34/150
# 6899/6899 [==============================] - 2s 352us/step - loss: 0.6387 - acc: 0.7540 - val_loss: 1.0488 - val_acc: 0.6216
#
# Epoch 00034: val_acc did not improve from 0.63784
# Epoch 35/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6530 - acc: 0.7584 - val_loss: 1.0648 - val_acc: 0.6162
#
# Epoch 00035: val_acc did not improve from 0.63784
# Epoch 36/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6341 - acc: 0.7575 - val_loss: 1.0597 - val_acc: 0.6162
#
# Epoch 00036: val_acc did not improve from 0.63784
# Epoch 37/150
# 6899/6899 [==============================] - 2s 350us/step - loss: 0.6250 - acc: 0.7624 - val_loss: 1.0692 - val_acc: 0.6216
#
# Epoch 00037: val_acc did not improve from 0.63784
# Epoch 38/150
# 6899/6899 [==============================] - 2s 352us/step - loss: 0.6225 - acc: 0.7617 - val_loss: 1.1085 - val_acc: 0.6270
#
# Epoch 00038: val_acc did not improve from 0.63784
# Epoch 39/150
# 6899/6899 [==============================] - ETA: 0s - loss: 0.6245 - acc: 0.774 - 2s 355us/step - loss: 0.6228 - acc: 0.7746 - val_loss: 1.0901 - val_acc: 0.6108
#
# Epoch 00039: val_acc did not improve from 0.63784
# Epoch 40/150
# 6899/6899 [==============================] - 2s 354us/step - loss: 0.6278 - acc: 0.7649 - val_loss: 1.0482 - val_acc: 0.6378
#
# Epoch 00040: val_acc did not improve from 0.63784
# Epoch 00040: early stopping
# Test score: 1.0482424226967064
# Test accuracy: 0.6378378410597105
